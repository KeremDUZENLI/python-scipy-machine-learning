# %% [markdown]
# # **_INSTALL DEPENDENCIES_**

# %%
import os
import os.path as op
from urllib.request import urlretrieve
from IPython.display import Markdown, display


def create_folder(folder):
    if not op.exists(folder):
        os.mkdir(folder)
        print(f"Creating:\t\t {folder}")
    else:
        print(f"Already exist:\t\t {folder}")

def download_file(url, filename):
    if not op.exists(filename):
        print(f"Downloading:\t\t {url} --> {filename}")
        urlretrieve(url, filename)
    else:
        print(f"Already downloaded:\t {url} --> {filename}")


FILES = "Files"
EX7DATA1_URL = "https://raw.githubusercontent.com/KeremDUZENLI/python-jupyter-machine-learning/refs/heads/main/notebooks/Files/ex7data1.pkl"
EX7DATA1 = FILES + "/ex7data1.pkl"
EX7DATA2_URL = "https://raw.githubusercontent.com/KeremDUZENLI/python-jupyter-machine-learning/refs/heads/main/notebooks/Files/ex7data2.pkl"
EX7DATA2 = FILES + "/ex7data2.pkl"
EX7FACES_URL = "https://raw.githubusercontent.com/KeremDUZENLI/python-jupyter-machine-learning/refs/heads/main/notebooks/Files/ex7faces.pkl"
EX7FACES = FILES + "/ex7faces.pkl"
EX7SMALLBIRD_URL = "https://raw.githubusercontent.com/KeremDUZENLI/python-jupyter-machine-learning/refs/heads/main/notebooks/Files/ex7smallbird.png"
EX7SMALLBIRD = FILES + "/ex7smallbird.png"

with open('../README.md', 'r', encoding='utf-8') as f:
    display(Markdown(f.read()))
create_folder(FILES)
download_file(EX7DATA1_URL, EX7DATA1)
download_file(EX7DATA2_URL, EX7DATA2)
download_file(EX7FACES_URL, EX7FACES)
download_file(EX7SMALLBIRD_URL, EX7SMALLBIRD)
# Out:
# # Deep Learning Examples
#
# A collection of machine learning examples. Based on the course **Machine Learning Basics**, University of Debrecen.
#
# ## Project Directory (Colab Version)
#
# You can access the Colab version of the project directly on Link:
#
# [drive.google.com/drive/folders/1J1P-MPw_w8uqze2SuIxIy8AySrrAyc5l?usp=sharing](https://drive.google.com/drive/folders/1J1P-MPw_w8uqze2SuIxIy8AySrrAyc5l?usp=sharing)
#
# ## Project Directory (Standalone Version)
#
# You can access the non-Colab version of the project directly on GitHub:
#
# [github.com/KeremDUZENLI/python-jupyter-machine-learning](https://github.com/KeremDUZENLI/python-jupyter-machine-learning)
#
# ## Install
#
# 1. Download Python 3.6.8: [Python 3.6.8 Download](https://www.python.org/downloads/release/python-368/)
# 2. Check Python versions installed: `py -0`
# 3. Check the default version: `python --version`
# 4. Check python locations: `where python`
# 5. Verify python 3.6.x location: `...\AppData\Local\Programs\Python\Python36\python.exe`
#
# ## Setup
#
# 1. Clone the repository:
#    ```sh
#    git clone https://github.com/KeremDUZENLI/python-jupyter-machine-learning.git
#    ```
# 2. Create a virtual environment:
#    ```sh
#    ...\AppData\Local\Programs\Python\Python36\python.exe -m venv myEnv
#    ```
# 3. Activate the virtual environment:
#    - **Windows**: `myEnv\Scripts\activate`
#    - **Linux/macOS**: `source myEnv/bin/activate`
# 4. Update pip:
#    ```sh
#    python -m pip install --upgrade pip
#    ```
# 5. Update setuptools:
#    ```sh
#    pip install --upgrade setuptools
#    ```
# 6. Install dependencies:
#    ```sh
#    pip install -r requirements.txt
#    ```
# 7. Freeze dependencies (optional):
#    ```sh
#    python -m pip freeze > requirements.txt
#    ```
#
# ## Notebooks
#
# 1. Install Jupyter:
#    ```sh
#    pip install jupyterlab
#    ```
# 2. Register Python Environment:
#    ```sh
#    pip install jupyterlab ipykernel
#    python -m ipykernel install --user --name=myEnv --display-name "Python (myEnv)"
#    ```
# 3. Launch Jupyter:
#    ```sh
#    jupyter lab
#    ```
# 4. Change Kernel:
#    ```sh
#    Change kernel in Jupyterlab (Select after choosing the .ipynb file) =
#    Kernel → Change Kernel → Python (myEnv)
#    ```
#
# ## Quick Run (after installation)
#
# 1. Activate the virtual environment:
#    - **Windows**: `myEnv\Scripts\activate`
#    - **Linux/macOS**: `source myEnv/bin/activate`
# 2. Launch Jupyter:
#    ```sh
#    jupyter lab
#    ```
# 3. Change Kernel (if needed):
#    ```sh
#    Change kernel in Jupyterlab (Select after choosing the .ipynb file) =
#    Kernel → Change Kernel → Python (myEnv)
#    ```
#
# ### Notebook Descriptions
#
# - [1. Linear Regression](notebooks/1_linear_regression.ipynb) – Predicts continuous values using fitted linear models.
# - [2. Logictic Regression](notebooks/2_logistic_regression.ipynb) - Performs binary classification with a sigmoid-based model.
# - [3. Multiclass Classification](notebooks/3_multiclass_classification.ipynb) - Classifies inputs into multiple classes using one-vs-all.
# - [4. Neural Network Back Propagation](notebooks/4_nn_back_propagation.ipynb) - Trains a neural network using forward and backward passes.
# - [5. Bias vs. Variance](notebooks/5_bias_vs_variance.ipynb) - Examines underfitting and overfitting via learning curves.
# - [6. Support Vector Machine (SVM)](notebooks/6_support_vector_machine.ipynb) - Classifies data using linear or kernel-based support vector machines.
# - [7. K-Mean Clustering](notebooks/7_k_means_clustering.ipynb) - Groups data into clusters for unsupervised learning.
#
# ## Acknowledgments
#
# This project is based on the **Machine Learning Basics** course at the **University of Debrecen**
#
# - **Prof. Dr. András Hajdu** – Dean, Head of Department
#
#   - _Department of Data Science and Visualization, Faculty of Informatics, University of Debrecen_
#   - Email: [hajdu.andras@inf.unideb.hu](mailto:hajdu.andras@inf.unideb.hu)
#
# - **Dr. Balázs Harangi** – Associate Professor, Deputy Head of Department
#
#   - _Department of Data Science and Visualization, Faculty of Informatics, University of Debrecen_
#   - Email: [harangi.balazs@inf.unideb.hu](mailto:harangi.balazs@inf.unideb.hu)
#
# - **Kerem Düzenli** – PhD Candidate, University of Debrecen
#
#   - _Creator and maintainer of this repository_
#   - Email: [kerem.duzenli@inf.unideb.hu](mailto:kerem.duzenli@inf.unideb.hu)
#
# ## Contributing
#
# 1. Fork the repository.
# 2. Create a new branch:
#    ```sh
#    git checkout -b YourBranch
#    ```
# 3. Make your changes and commit them:
#    ```sh
#    git commit -m "Add some feature"
#    ```
# 4. Push to the branch:
#    ```sh
#    git push origin YourBranch
#    ```
# 5. Open a pull request.
#
# ## License
#
# This project is licensed under the **Creative Commons Attribution-NonCommercial 4.0 International (CC BY-NC 4.0)** license. This means you are free to:
#
# - **Share** – Copy and redistribute the material in any medium or format.
# - **Adapt** – Remix, transform, and build upon the material.
#
# However, **you may not use the material for commercial purposes**.
#
# For details, see the [LICENSE](LICENSE) file or read more at [Creative Commons](https://creativecommons.org/licenses/by-nc/4.0/).
#
# ## Disclaimer
#
# This repository is intended **only for educational and research purposes**. The authors and contributors assume no responsibility for misuse of the code or any implications arising from its use.
#
# ## Support My Work
#
# If you find this resource valuable and would like to help support my education and doctoral research, please consider treating me to a cup of coffee (or tea) via Revolut.
#
# <div align="center">
#   <a href="https://revolut.me/krmdznl" target="_blank">
#     <img src="https://img.shields.io/badge/Support%20My%20Projects-Donate%20via%20Revolut-orange?style=for-the-badge" alt="Support my education via Revolut" />
#   </a>
# </div> <br>
# Already exist:		 Files
# Already downloaded:	 https://raw.githubusercontent.com/KeremDUZENLI/python-jupyter-machine-learning/refs/heads/main/notebooks/Files/ex7data1.pkl --> Files/ex7data1.pkl
# Already downloaded:	 https://raw.githubusercontent.com/KeremDUZENLI/python-jupyter-machine-learning/refs/heads/main/notebooks/Files/ex7data2.pkl --> Files/ex7data2.pkl
# Already downloaded:	 https://raw.githubusercontent.com/KeremDUZENLI/python-jupyter-machine-learning/refs/heads/main/notebooks/Files/ex7faces.pkl --> Files/ex7faces.pkl
# Downloading:		 https://raw.githubusercontent.com/KeremDUZENLI/python-jupyter-machine-learning/refs/heads/main/notebooks/Files/ex7bird.png --> https://raw.githubusercontent.com/KeremDUZENLI/python-jupyter-machine-learning/refs/heads/main/notebooks/Files/ex7bird.png
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-2-0b19ee1041b7> in <module>
#      36 download_file(EX7DATA2_URL, EX7DATA2)
#      37 download_file(EX7FACES_URL, EX7FACES)
# ---> 38 download_file(EX7BIRD_URL, EX7BIRD_URL)
#
# <ipython-input-2-0b19ee1041b7> in download_file(url, filename)
#      15     if not op.exists(filename):
#      16         print(f"Downloading:\t\t {url} --> {filename}")
# ---> 17         urlretrieve(url, filename)
#      18     else:
#      19         print(f"Already downloaded:\t {url} --> {filename}")
#
# ~\AppData\Local\Programs\Python\Python36\lib\urllib\request.py in urlretrieve(url, filename, reporthook, data)
#     246     url_type, path = splittype(url)
#     247
# --> 248     with contextlib.closing(urlopen(url, data)) as fp:
#     249         headers = fp.info()
#     250
#
# ~\AppData\Local\Programs\Python\Python36\lib\urllib\request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     221     else:
#     222         opener = _opener
# --> 223     return opener.open(url, data, timeout)
#     224
#     225 def install_opener(opener):
#
# ~\AppData\Local\Programs\Python\Python36\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     530         for processor in self.process_response.get(protocol, []):
#     531             meth = getattr(processor, meth_name)
# --> 532             response = meth(req, response)
#     533
#     534         return response
#
# ~\AppData\Local\Programs\Python\Python36\lib\urllib\request.py in http_response(self, request, response)
#     640         if not (200 <= code < 300):
#     641             response = self.parent.error(
# --> 642                 'http', request, response, code, msg, hdrs)
#     643
#     644         return response
#
# ~\AppData\Local\Programs\Python\Python36\lib\urllib\request.py in error(self, proto, *args)
#     568         if http_err:
#     569             args = (dict, 'default', 'http_error_default') + orig_args
# --> 570             return self._call_chain(*args)
#     571
#     572 # XXX probably also want an abstract factory that knows when it makes
#
# ~\AppData\Local\Programs\Python\Python36\lib\urllib\request.py in _call_chain(self, chain, kind, meth_name, *args)
#     502         for handler in handlers:
#     503             func = getattr(handler, meth_name)
# --> 504             result = func(*args)
#     505             if result is not None:
#     506                 return result
#
# ~\AppData\Local\Programs\Python\Python36\lib\urllib\request.py in http_error_default(self, req, fp, code, msg, hdrs)
#     648 class HTTPDefaultErrorHandler(BaseHandler):
#     649     def http_error_default(self, req, fp, code, msg, hdrs):
# --> 650         raise HTTPError(req.full_url, code, msg, hdrs, fp)
#     651
#     652 class HTTPRedirectHandler(BaseHandler):
#
# HTTPError: HTTP Error 404: Not Found

# %% [markdown]
# # Step 1: Helper Functions

# %%
import numpy as np
import matplotlib.pyplot as plt
import pickle
import math
from sklearn.svm import SVC
from itertools import product

# %%
def gaussian_kernel(x1, x2, sigma=0.1):
    """Compute the Gaussian (RBF) kernel between two vectors."""
    return np.exp(-np.sum((x1 - x2)**2) / (2 * sigma**2))

# %%
def train_svm(X, y, C=1.0, sigma=0.1):
    """Train an SVM with RBF kernel."""
    gamma = 1 / (2 * sigma**2)  # scikit-learn expects gamma
    model = SVC(C=C, kernel='rbf', gamma=gamma)
    model.fit(X, y.ravel())

    return model

# %%
def predict_svm(model, X):
    return model.predict(X)

# %%
def dataset3_params(X, y, Xval, yval, C_values, sigma_values):
    best_score = 0
    best_params = (C_values[0], sigma_values[0])
    
    for C, sigma in product(C_values, sigma_values):
        model = train_svm(X, y, C, sigma)
        predictions = predict_svm(model, Xval)
        score = np.mean(predictions == yval.ravel())
        if score > best_score:
            best_score = score
            best_params = (C, sigma)
    
    return best_params

# %%
def find_closest_centroids(X, centroids):
    """
    Assign each example in X to the closest centroid.

    :param X: m x n matrix of examples
    :param centroids: K x n matrix of centroids
    :return: idx, vector of centroid assignments (length m)
    """
    m = X.shape[0]
    K = centroids.shape[0]
    idx = np.zeros(m, dtype=int)
    
    for i in range(m):
        distances = np.zeros(K)
        for k in range(K):
            distances[k] = np.sum((X[i] - centroids[k])**2)
        idx[i] = np.argmin(distances)
    
    return idx

# %%
def compute_centroids(X, idx, K):
    """
    Compute new centroids by averaging the points assigned to each centroid.

    :param X: m x n matrix of examples
    :param idx: vector of centroid assignments
    :param K: number of centroids
    :return: centroids, K x n matrix
    """
    n = X.shape[1]
    centroids = np.zeros((K, n))
    
    for k in range(K):
        points = X[idx == k]
        if len(points) > 0:
            centroids[k] = np.mean(points, axis=0)
    
    return centroids

# %%
def run_kmeans(X, initial_centroids, max_iters, plot_progress=False):
    """
    Run K-Means algorithm on dataset X.

    :param X: m x n data matrix
    :param initial_centroids: K x n matrix
    :param max_iters: number of iterations
    :param plot_progress: if True, plot centroids progress
    :return: final centroids, centroid assignments
    """
    centroids = initial_centroids.copy()
    K = centroids.shape[0]
    idx = None

    for i in range(max_iters):
        # Step 1: assign clusters
        idx = find_closest_centroids(X, centroids)
        
        # Optional plot
        if plot_progress:
            plt.figure(figsize=(6, 4))
            plt.scatter(X[:, 0], X[:, 1], c=idx, cmap='viridis', s=50)
            plt.scatter(centroids[:, 0], centroids[:, 1], marker='x', c='red', s=200, linewidths=3)
            plt.title(f"K-Means iteration {i+1}")
            plt.xlabel("X1")
            plt.ylabel("X2")
            plt.show()
        
        # Step 2: recompute centroids
        centroids = compute_centroids(X, idx, K)

    return centroids, idx

# %%
def kmeans_init_centroids(X, K):
    """
    Initialize K centroids by randomly sampling from the dataset X.
    """
    m = X.shape[0]
    indices = np.random.choice(m, K, replace=False)
    return X[indices]

# %%
def feature_normalize(X):
    """Normalize each feature to have mean 0 and std 1."""
    mu = np.mean(X, axis=0)
    sigma = np.std(X, axis=0)
    X_norm = (X - mu) / sigma

    return X_norm, mu, sigma

# %%
def pca(X):
    """
    Perform Principal Component Analysis.
    Returns eigenvectors U and eigenvalues S.
    """
    m = X.shape[0]
    Sigma = (X.T @ X) / m
    U, S, _ = np.linalg.svd(Sigma)

    return U, np.diag(S)

# %%
def draw_line(p1, p2, style='-k', LineWidth=2):
    plt.plot([p1[0], p2[0]], [p1[1], p2[1]], style, linewidth=LineWidth)

# %%
def project_data(X, U, K):
    """
    Projects the data X onto the first K eigenvectors in U.
    Returns the projected data Z.
    """
    U_reduced = U[:, :K]
    Z = X @ U_reduced

    return Z

# %%
def recover_data(Z, U, K):
    """
    Recovers an approximation of the original data from Z using first K eigenvectors in U.
    """
    U_reduced = U[:, :K]
    X_rec = Z @ U_reduced.T

    return X_rec

# %%
def display_data(X, ax=None):
    """
    Displays 2D data stored in X in a grid.
    X: each row is an example, assumed to be a square image (e.g., 20x20).
    ax: matplotlib Axes object (optional)
    """
    if X.ndim == 1:
        X = X.reshape(1, -1)
    
    m, n = X.shape
    example_width = int(round(math.sqrt(n)))
    example_height = n // example_width
    
    # Compute rows/cols for display grid
    display_rows = int(math.floor(math.sqrt(m)))
    display_cols = int(math.ceil(m / display_rows))
    
    # Padding between images
    pad = 1
    display_array = -np.ones((pad + display_rows * (example_height + pad),
                               pad + display_cols * (example_width + pad)))
    
    curr_ex = 0
    for i in range(display_rows):
        for j in range(display_cols):
            if curr_ex >= m:
                break
            # Copy image
            top = pad + i * (example_height + pad)
            left = pad + j * (example_width + pad)
            img = X[curr_ex].reshape(example_height, example_width)
            display_array[top:top+example_height, left:left+example_width] = img
            curr_ex += 1
    
    if ax is None:
        plt.imshow(display_array, cmap='gray')
        plt.axis('off')
    else:
        ax.imshow(display_array, cmap='gray')
        ax.axis('off')

# %% [markdown]
# # Step 2: Load the Data

# %%
with open(EX7DATA2, 'rb') as f:
    X = pickle.load(f)  # X is already a NumPy array

print("X shape:", X.shape)
# Out:
# X shape: (300, 2)

# %% [markdown]
# ## Step 2.1: Visualize the Dataset

# %%
plt.style.use('seaborn-whitegrid')

plt.scatter(X[:,0], X[:,1], s=50, c='blue')
plt.title("Example 2D Data")
plt.xlabel("X1")
plt.ylabel("X2")
plt.show()

# %% [markdown]
# # Step 3: K-Means - Initialization

# %%
K = 3  # number of clusters
initial_centroids = np.array([[3, 3], [6, 2], [8, 5]])

# Find closest centroids
idx = find_closest_centroids(X, initial_centroids)
print("Closest centroids for first 3 examples:\n", idx[:3])

# Compute new centroids
centroids = compute_centroids(X, idx, K)
print("Computed centroids:\n", centroids)
# Out:
# Closest centroids for first 3 examples:
#  [0 2 1]
# Computed centroids:
#  [[2.42830111 3.15792418]
#  [5.81350331 2.63365645]
#  [7.11938687 3.6166844 ]]

# %% [markdown]
# # Step 4: Run K-Means Clustering

# %%
max_iters = 3
centroids, idx = run_kmeans(X, initial_centroids, max_iters, plot_progress=True)

print("Final centroids:\n", centroids)
# Out:
# Final centroids:
#  [[2.19692479 3.42136707]
#  [4.83555397 2.12976745]
#  [6.6560054  3.0751355 ]]

# %% [markdown]
# # Step 5: PCA Example

# %%
with open(EX7DATA1, 'rb') as fin:
    X = pickle.load(fin)

# Normalize features
X_norm, mu, sigma = feature_normalize(X)

# Run PCA
U, S = pca(X_norm)

# Visualize top eigenvectors
draw_line(mu, mu + 1.5*S[0,0]*U[:,0].T, '-k', LineWidth=2)
draw_line(mu, mu + 1.5*S[1,1]*U[:,1].T, '-k', LineWidth=2)
plt.scatter(X_norm[:,0], X_norm[:,1], s=50)
plt.title("PCA - Eigenvectors")
plt.show()

# %% [markdown]
# # Step 6: Dimension Reduction

# %%
K = 1  # project onto 1 dimension
Z = project_data(X_norm, U, K)
X_rec = recover_data(Z, U, K)

print("Original vs Recovered (first example):")
print("Original:", X_norm[0,:])
print("Recovered:", X_rec[0,:])
# Out:
# Original vs Recovered (first example):
# Original: [-0.52331306 -1.59279252]
# Recovered: [-1.05805279 -1.05805279]

# %% [markdown]
# # Step 7: PCA on Faces Dataset

# %%
with open(EX7FACES, 'rb') as fin:
    X_faces = pickle.load(fin)

# Normalize
X_faces_norm, mu, sigma = feature_normalize(X_faces)

# Run PCA
U, S = pca(X_faces_norm)

# Display top 36 eigenfaces
display_data(U[:, 0:36].T)
plt.title("Top 36 Eigenfaces")
plt.show()

# Project onto K=100 dimensions
K = 100
Z_faces = project_data(X_faces_norm, U, K)
X_rec_faces = recover_data(Z_faces, U, K)

# Compare original vs reconstructed
fig, (ax0, ax1) = plt.subplots(1, 2, figsize=(12,6))
display_data(X_faces_norm[0:100,:], ax=ax0)
ax0.set_title("Original Faces")
display_data(X_rec_faces[0:100,:], ax=ax1)
ax1.set_title("Recovered Faces")
plt.show()

# %% [markdown]
# # Step 8: K-Means Image Compression

# %%
# Load image
A = plt.imread(EX7SMALLBIRD_URL)
img_size = A.shape
X_img = np.reshape(A, (img_size[0]*img_size[1], 3))

# Run K-Means
K = 16
max_iters = 10
initial_centroids = kmeans_init_centroids(X_img, K)
centroids, idx = run_kmeans(X_img, initial_centroids, max_iters)

# Compress image
X_recovered = centroids[idx, :]
X_recovered = np.reshape(X_recovered, (img_size[0], img_size[1], 3))

# Show original vs compressed
fig, (ax0, ax1) = plt.subplots(1,2)
ax0.imshow(A)
ax0.set_title("Original")
ax1.imshow(X_recovered)
ax1.set_title(f"Compressed with {K} colors")
plt.show()
